# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
tweets = pd.read_json("my_tweets.json")
tweets.head()
# Out:
#                                                                 1   \
# sentiment_label                                           negative
# text_of_tweet    when modi promised “minimum government maximum...
# tweet_url          https://x.com/julie81/status/981423403281674814
#
#                                                                 2   \
# sentiment_label                                            neutral
# text_of_tweet    talk all the nonsense and continue all the dra...
# tweet_url        https://x.com/richardhester/status/42436883123...
#
#                                                                 3   \
# sentiment_label                                           positive
# text_of_tweet    what did just say vote for modi  welcome bjp t...
# tweet_url        https://x.com/williamsjoseph/status/5555614606...
#
#                                                                 4   \
# sentiment_label                                           positive
# ...

# %%
import pandas as pd

# Load the dataset
tweets = pd.read_json("my_tweets.json")

# Transpose the DataFrame
transposed = tweets.T

transposed.head()
# Out:
#   sentiment_label                                      text_of_tweet  \
# 1        negative  when modi promised “minimum government maximum...
# 2         neutral  talk all the nonsense and continue all the dra...
# 3        positive  what did just say vote for modi  welcome bjp t...
# 4        positive  asking his supporters prefix chowkidar their n...
# 5        positive  answer who among these the most powerful world...
#
#                                            tweet_url
# 1    https://x.com/julie81/status/981423403281674814
# 2  https://x.com/richardhester/status/42436883123...
# 3  https://x.com/williamsjoseph/status/5555614606...
# 4  https://x.com/danielsmary/status/2489181067362...
# 5  https://x.com/carlwarren/status/11465357322402...

# %%
transposed.describe()
# Out:
#        sentiment_label                                      text_of_tweet  \
# count               50                                                 50
# unique               3                                                 50
# top           positive  when modi promised “minimum government maximum...
# freq                21                                                  1
#
#                                               tweet_url
# count                                                50
# unique                                               50
# top     https://x.com/julie81/status/981423403281674814
# freq                                                  1
